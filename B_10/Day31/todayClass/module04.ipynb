# %%
import pandas as pd

# %%
df_car = pd.read_csv("./code/auto-mpg.csv",header = None)
df_car.columns=['mpg','cylnder','display','horsepower','weight','acceleration','model year','origin','name']
df_car
# Out:
#       mpg  cylnder  display horsepower weight  acceleration  model year  \
# 0    18.0        8    307.0      130.0  3504.          12.0          70
# 1    15.0        8    350.0      165.0  3693.          11.5          70
# 2    18.0        8    318.0      150.0  3436.          11.0          70
# 3    16.0        8    304.0      150.0  3433.          12.0          70
# 4    17.0        8    302.0      140.0  3449.          10.5          70
# ..    ...      ...      ...        ...    ...           ...         ...
# 393  27.0        4    140.0      86.00  2790.          15.6          82
# 394  44.0        4     97.0      52.00      ?          24.6          82
# 395  32.0        4    135.0      84.00  2295.          11.6          82
# 396  28.0        4    120.0      79.00  2625.          18.6          82
# 397  31.0        4    119.0      82.00  2720.          19.4          82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %% [markdown]
# 위 혹은 아래 일부 보여주기

# %%
# 젤 위에 있는 5개 보여줌
df_car.head()
# Out:
#     mpg  cylnder  display horsepower weight  acceleration  model year  origin  \
# 0  18.0        8    307.0      130.0  3504.          12.0          70       1
# 1  15.0        8    350.0      165.0  3693.          11.5          70       1
# 2  18.0        8    318.0      150.0  3436.          11.0          70       1
# 3  16.0        8    304.0      150.0  3433.          12.0          70       1
# 4  17.0        8    302.0      140.0  3449.          10.5          70       1
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
# 젤 위에 있는 10개 보여줌
df_car.head(10)
# Out:
#     mpg  cylnder  display horsepower weight  acceleration  model year  origin  \
# 0  18.0        8    307.0      130.0  3504.          12.0          70       1
# 1  15.0        8    350.0      165.0  3693.          11.5          70       1
# 2  18.0        8    318.0      150.0  3436.          11.0          70       1
# 3  16.0        8    304.0      150.0  3433.          12.0          70       1
# 4  17.0        8    302.0      140.0  3449.          10.5          70       1
# 5  15.0        8    429.0      198.0  4341.          10.0          70       1
# 6  14.0        8    454.0      220.0  4354.           9.0          70       1
# 7  14.0        8    440.0      215.0  4312.           8.5          70       1
# 8  14.0        8    455.0      225.0  4425.          10.0          70       1
# 9  15.0        8    390.0      190.0  3850.           8.5          70       1
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# ...

# %%
# 젤 뒤에 있는 10개 보여줌
df_car.tail(10)
# Out:
#       mpg  cylnder  display horsepower weight  acceleration  model year  \
# 388  26.0        4    156.0      92.00  2585.          14.5          82
# 389  22.0        6    232.0      112.0   2835          14.7          82
# 390  32.0        4    144.0      96.00  2665.          13.9          82
# 391  36.0        4    135.0      84.00  2370.          13.0          82
# 392  27.0        4    151.0      90.00  2950.          17.3          82
# 393  27.0        4    140.0      86.00  2790.          15.6          82
# 394  44.0        4     97.0      52.00      ?          24.6          82
# 395  32.0        4    135.0      84.00  2295.          11.6          82
# 396  28.0        4    120.0      79.00  2625.          18.6          82
# 397  31.0        4    119.0      82.00  2720.          19.4          82
#
#      origin                        name
# 388       1  chrysler lebaron medallion
# 389       1              ford granada l
# 390       3            toyota celica gt
# ...

# %%
df_car.shape    # 행 열
# Out:
# (398, 9)

# %%
df_car.info()
# object는 대부분 String
#non-null = null이 없다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    object
#  1   cylnder       398 non-null    int64
#  2   display       398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    object
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 28.1+ KB

# %%
# 데이터들의 각 열에 대한 통계를 보여준다
df_car.describe()
# Out:
#           cylnder     display  acceleration  model year      origin
# count  398.000000  398.000000    398.000000  398.000000  398.000000
# mean     5.454774  193.425879     15.568090   76.010050    1.572864
# std      1.701004  104.269838      2.757689    3.697627    0.802055
# min      3.000000   68.000000      8.000000   70.000000    1.000000
# 25%      4.000000  104.250000     13.825000   73.000000    1.000000
# 50%      4.000000  148.500000     15.500000   76.000000    1.000000
# 75%      8.000000  262.000000     17.175000   79.000000    2.000000
# max      8.000000  455.000000     24.800000   82.000000    3.000000

# %%
# 각각의 데이터 값이 몇개인지 알려준다
df_car.count()
# Out:
# mpg             398
# cylnder         398
# display         398
# horsepower      398
# weight          398
# acceleration    398
# model year      398
# origin          398
# name            398
# dtype: int64

# %%
# 집계 함수 (= 각 ㅕ열 다 더하기) - sum  
# horsepower는 String이었기에 저렇게 나온거다
df_car.sum()
# Out:
# mpg             18.015.018.016.017.015.014.014.014.015.015.014...
# cylnder                                                      2171
# display                                                   76983.5
# horsepower      130.0165.0150.0150.0140.0198.0220.0215.0225.01...
# weight          3504.3693.3436.3433.3449.4341.4354.4312.4425.3...
# acceleration                                               6196.1
# model year                                                  30252
# origin                                                        626
# name            chevrolet chevelle malibubuick skylark 320plym...
# dtype: object

# %%
df_car.mpg.min() # 연비가 젤 안 좋은 거
# Out:
# '10.0'

# %%
df_car.mpg.max() # 연비가 젤 좋은 거
# Out:
# '?'

# %%
# horsepower는 String이었기에 저렇게 나온거다
df_car.horsepower.sum()
# Out:
# '130.0165.0150.0150.0140.0198.0220.0215.0225.0190.0170.0160.0150.0225.095.0095.0097.0085.0088.0046.0087.0090.0095.00113.090.00215.0200.0210.0193.088.0090.0095.00?100.0105.0100.088.00100.0165.0175.0153.0150.0180.0170.0175.0110.072.00100.088.0086.0090.0070.0076.0065.0069.0060.0070.0095.0080.0054.0090.0086.00165.0175.0150.0153.0150.0208.0155.0160.0190.097.00150.0130.0140.0150.0112.076.0087.0069.0086.0092.0097.0080.0088.00175.0150.0145.0137.0150.0198.0150.0158.0150.0215.0225.0175.0105.0100.0100.088.0095.0046.00150.0167.0170.0180.0100.088.0072.0094.0090.0085.00107.090.00145.0230.049.0075.0091.00112.0150.0110.0122.0180.095.00?100.0100.067.0080.0065.0075.00100.0110.0105.0140.0150.0150.0140.0150.083.0067.0078.0052.0061.0075.0075.0075.0097.0093.0067.0095.00105.072.0072.00170.0145.0150.0148.0110.0105.0110.095.00110.0110.0129.075.0083.00100.078.0096.0071.0097.0097.0070.0090.0095.0088.0098.00115.053.0086.0081.0092.0079.0083.00140.0150.0120.0152.0100.0105.081.0090.0052.0060.0070.0053.00100.078.00
# ...

# %%
# median = 중간값, mean = 평균
df_car.mpg.median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py:752, in nanmedian(values, axis, skipna, mask)
#     751 try:
# --> 752     values = values.astype("f8")
#     753 except ValueError as err:
#     754     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '?'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /home/nhnacademy/문서/nhnacademy/B_10/Day31/todayClass/module04.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/nhnacademy/%EB%AC%B8%EC%84%9C/nhnacademy/B_10/Day31/todayClass/module04.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # median = 중간값, mean = 평균
# ...

# %%
df_car.mpg.mean()
# Out:
# 23.514572864321615

# %%
# horsepower가 가지고 있는 data들의 고유 값만 보여줌 = 가지고 있는 값들의 종류만 보여줌
df_car.horsepower.unique()
# 여기서 ?가 뜨면 그건 측정 불가라는 말이다
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
df_car2 = df_car.copy()

# %%
mask = df_car2['weight'] == '?'     # 둘이 같으면 True, 다르면 False
mask
df_car2.loc[mask] =0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394     True
# 395    False
# 396    False
# 397    False
# Name: weight, Length: 398, dtype: bool

# %%
df_car2
# Out:
#       mpg  cylnder  display horsepower weight  acceleration  model year  \
# 0    18.0        8    307.0      130.0  3504.          12.0          70
# 1    15.0        8    350.0      165.0  3693.          11.5          70
# 2    18.0        8    318.0      150.0  3436.          11.0          70
# 3    16.0        8    304.0      150.0  3433.          12.0          70
# 4    17.0        8    302.0      140.0  3449.          10.5          70
# ..    ...      ...      ...        ...    ...           ...         ...
# 393  27.0        4    140.0      86.00  2790.          15.6          82
# 394     0        0      0.0          0      0           0.0           0
# 395  32.0        4    135.0      84.00  2295.          11.6          82
# 396  28.0        4    120.0      79.00  2625.          18.6          82
# 397  31.0        4    119.0      82.00  2720.          19.4          82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df_car.horsepower.unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
# 방법 1
# df_cars2.replace({'horse':'?'},0)

# 방법 2
# df_car2['horsepower'] = df_car2['horsepower'].str.replace('?','0.0').astype(float)
# df_car2.horsepower.unique()

# %%
df_car2.sum()
# Out:
# mpg                                                        9358.8
# cylnder                                                      2171
# display                                                   76983.5
# horsepower      130.0165.0150.0150.0140.0198.0220.0215.0225.01...
# weight                                                  1182229.0
# acceleration                                               6196.1
# model year                                                  30252
# origin                                                        626
# name            chevrolet chevelle malibubuick skylark 320plym...
# dtype: object
