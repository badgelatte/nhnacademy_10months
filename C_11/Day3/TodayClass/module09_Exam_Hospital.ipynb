# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] = 'NanumGothic'

# %%
liver = pd.DataFrame(pd.read_excel('./code/5대질병/간질환/간.xlsx'))
cancel = pd.DataFrame(pd.read_excel('./code/5대질병/암/암_최종본.xlsx'))
c = pd.DataFrame(pd.read_excel('./code/5대질병/당뇨병.xlsx'))
b = pd.DataFrame(pd.read_excel('./code/5대질병/뇌혈관질환.xlsx'))
a = pd.DataFrame(pd.read_excel('./code/5대질병/뇌혈관질환.xlsx'))
# Out:
# /home/nhnacademy/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /home/nhnacademy/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /home/nhnacademy/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
c.columns = c.iloc[2]
c
# Out:
# 2    항목  성별구분  연령구분10세        환자수       내원일수       청구건수    요양급여비용총액  \
# 0   NaN   NaN      NaN        NaN        NaN        NaN         NaN
# 1   NaN   NaN     진료년월  2022년 01월        NaN        NaN         NaN
# 2    항목  성별구분  연령구분10세        환자수       내원일수       청구건수    요양급여비용총액
# 3   당뇨병     계        계  1669975.0  2167544.0  2044081.0  92026757.0
# 4   당뇨병     남       소계   926777.0  1187308.0  1126321.0  51768520.0
# 5   당뇨병     남     0_9세      145.0      287.0      218.0     61293.0
# 6   당뇨병     남   10_19세     2089.0     3289.0     3004.0    304917.0
# 7   당뇨병     남   20_29세     7435.0    10217.0     9579.0    692709.0
# 8   당뇨병     남   30_39세    31677.0    40603.0    39015.0   2138961.0
# 9   당뇨병     남   40_49세   117039.0   144717.0   139770.0   6466599.0
# 10  당뇨병     남   50_59세   237562.0   291143.0   281929.0  11941478.0
# 11  당뇨병     남   60_69세   294792.0   369972.0   355372.0  14944711.0
# 12  당뇨병     남   70_79세   174097.0   233052.0   217634.0  10278418.0
# ...

# %%
df = c[(c.columns == '환자수')]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/nhnacademy/문서/nhnacademy/C_11/Day3/TodayClass/module09_Exam_Hospital.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/nhnacademy/%EB%AC%B8%EC%84%9C/nhnacademy/C_11/Day3/TodayClass/module09_Exam_Hospital.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = c[(c.columns == '환자수')]
#       <a href='vscode-notebook-cell:/home/nhnacademy/%EB%AC%B8%EC%84%9C/nhnacademy/C_11/Day3/TodayClass/module09_Exam_Hospital.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3496, in DataFrame.__getitem__(self, key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
# -> 3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
# ...
