# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] = 'NanumGothic'

# %%
import os
# os.listdir('./code/5대질병/간질환/')
liverpath = './code/5대질병/간질환/'
liverfolders = os.listdir(liverpath)
liverfolders
# Out:
# ['지방간.xlsx', '간의질환.xlsx', '간경변증.xlsx']

# %%
df_liver = pd.DataFrame()
df_livers = pd.DataFrame()
for liver in liverfolders:
    # print(type(liver))
    liverfind=os.path.join(liverpath,liver)
    # print(liverfind)
    df_liver = pd.read_excel(liverfind)
    df = df_liver.rename(columns = df_liver.iloc[2])
    df = df.drop(0,axis=0)
    df = df.drop(2,axis=0)
    df = df.drop('항목',axis=1)
    # print(df.info())

    # 여기서 선택권은 2가지 
    # float형으로 바꿔서 해당범위만 더하게 하기 or 글자들 따로 빼서 값들만 있는 표 만들어서 float형변환 후 더하고 따로 빼놓은 글자들 다시 합치기
    # .... 응 그냥 excel 써~
    df_gender = df.iloc[0]
    # df.astype(float) #-> object를 float형으로 바꾸기
    # df_livers = df_livers.iloc[3:3,23:62]+df.iloc[3:3,23:62]  
df_gender
# df_livers
# Out:
# /home/nhnacademy/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /home/nhnacademy/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /home/nhnacademy/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 성별구분              NaN
# 연령구분10세          진료년월
# 환자수         2022년 01월
# 내원일수              NaN
# 청구건수              NaN
#               ...
# 환자수         2022년 12월
# 내원일수              NaN
# 청구건수              NaN
# 요양급여비용총액          NaN
# 보험자부담금            NaN
# ...

# %%
# df_liver.index[2]
# df_liver.drop(df_liver.index[0],axis=0,inplace=True)
# df_liver.drop(df_liver.iloc[0],axis=0,inplace=True)

# df_liver

# %%
# df = df_liver.drop(df_liver.index[1],axis=0)

df
# Out:
#    성별구분 연령구분10세        환자수     내원일수     청구건수    요양급여비용총액      보험자부담금  \
# 1   NaN    진료년월  2022년 01월      NaN      NaN         NaN         NaN
# 3     계       계    30570.0  72897.0  44321.0  18698188.0  13642027.0
# 4     남      소계    19275.0  46294.0  27849.0  12226792.0   8900273.0
# 5     남    0_9세        4.0      7.0      5.0      2099.0      1738.0
# 6     남  10_19세        8.0     12.0     12.0      1085.0       841.0
# 7     남  20_29세       57.0    195.0     87.0     74390.0     55931.0
# 8     남  30_39세      473.0   1525.0    699.0    719384.0    566757.0
# 9     남  40_49세     2189.0   6205.0   3215.0   2231032.0   1705928.0
# 10    남  50_59세     5585.0  13556.0   8181.0   3822234.0   2798955.0
# 11    남  60_69세     6751.0  15545.0   9685.0   3620673.0   2572880.0
# 12    남  70_79세     3383.0   6937.0   4758.0   1268064.0    850539.0
# 13    남   80세이상      842.0   2312.0   1207.0    487832.0    346704.0
# 14    여      소계    11295.0  26603.0  16472.0   6471396.0   4741753.0
# ...
